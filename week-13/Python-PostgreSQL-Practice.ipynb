# %% [markdown]
# # Python - PostgreSQL

# %% [markdown]
# <ul><li>PostgreSQL can be integrated with Python using psycopg2 module.</li><li>psycopg2 is a PostgreSQL database adapter for the Python programming language.</li><li>psycopg2 was written with the aim of being very small and fast, and stable as a rock.</li><li> You do not need to install this module separately because it is shipped, by default, along with Python version 2.5.x onwards.</li></ul>

# %% [markdown]
# # Python psycopg2 Module APIs
#
# If you do not have it installed on your machine then you can use the command to install it as follows:

# %%
pip install psycopg2

# %% [markdown]
# If the above command causes an error then use the command:

# %%
pip install psycopg2-binary

# %% [markdown]
# The following are important psycopg2 module routines:

# %% [markdown]
# <table border=1 style="font-size:15px;">
#     <tr>
#         <td width=200><b>APIs</b></td><td width=800><b>Description</b></td>
#     </tr>
#     <tr>
#         <td>psycopg2.connect()</td><td>This API opens a connection to the PostgreSQL database.</td>
#     </tr>
#      <tr>
#         <td>connection.cursor()</td><td>This routine creates a cursor which will be used throughout of your database programming with Python.</td>
#     </tr>
#     <tr>
#         <td>cursor.execute()</td><td>This routine executes an SQL statement. The SQL statement may be parameterized (i.e., placeholders instead of SQL literals).</td>
#     </tr>
#      <tr>
#         <td>connection.close()</td><td>DescriptionThis method closes the database connection.</td>
#     </tr>
#     <tr>
#         <td>cursor.fetchone()</td><td>This method fetches the next row of a query result set, returning a single sequence, or None when no more data is available.</td>
#     </tr>
#      <tr>
#         <td>cursor.fetchall()</td><td>This routine fetches all (remaining) rows of a query result, returning a list. An empty list is returned when no rows are available.</td>
#     </tr>
#     <tr>
#         <td>psycopg2.connect()</td><td>This API opens a connection to the PostgreSQL database.</td>
#     </tr>
# </table>

# %% [markdown]
# # Connecting to a Database

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "postgres"
user = "postgres"
password = "cos101"

# Establish the connection
try:
    connections = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connections.cursor()

    # Execute a SQL query
    cursor.execute("SELECT version();")
    
    # Fetch and print the result of the query
    db_version = cursor.fetchone()
    print(f"PostgreSQL database version: {db_version}")

    # Close the cursor and connection
    cursor.close()
    connections.close()

except Exception as error:
    print(f"Error connecting to PostgreSQL DB: {error}")
# Out:
# Connection to PostgreSQL DB successful
# PostgreSQL database version: ('PostgreSQL 16.1, compiled by Visual C++ build 1937, 64-bit',)

# %% [markdown]
# # Selecting existing Database

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "cos101_db"
user = "postgres"
password = "cos101"

# Establish the connection
try:
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL SELECT query
    select_query = "SELECT * FROM company;"

    # Execute the query
    cursor.execute(select_query)

    # Fetch all rows from the executed query
    data = cursor.fetchall()

    print("column", " | ", "column2")
    print("------------------------")
        
    # Iterate through the rows and print them
    for row in data:
        print(f"{row[0]}       |  {row[1]}")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error connecting to PostgreSQL DB: {error}")
# Out:
# Connection to PostgreSQL DB successful
# column  |  column2
# ------------------------
# 1       |  Chuka
# 2       |  Ethel
# 3       |  Adenike
# 4       |  Hassan
# 5       |  David
# 6       |  Chisom

# %% [markdown]
# # Create a new Database

# %%
import psycopg2
from psycopg2 import sql

# Parameters to connect to the existing PostgreSQL server
host = "localhost"
port = "5432"
dbname = "postgres"
user = "postgres"
password = "cos101"
  # Connect to the default database

# Name of the new database to be created
new_ddname = "cos102_db"

try:
    # Connect to the PostgreSQL server
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL server successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new database
    create_db_query = sql.SQL("CREATE DATABASE {}").format(sql.Identifier(new_ddname))

    # Execute the SQL statement
    cursor.execute(create_db_query)
    print(f"Database '{new_ddname}' created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating the database: {error}")
# Out:
# Connection to PostgreSQL server successful
# Database 'cos102_db' created successfully

# %% [markdown]
# # Create a Table

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "cos102_db"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    #connection.autocommit = True  # Enable autocommit mode
    connection.autocommit = True
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new table
    create_table_query = """
    CREATE TABLE sst_info (
        id SERIAL PRIMARY KEY,
        name VARCHAR(50) NOT NULL,
        age INT NOT NULL,
        department VARCHAR NOT NULL,
        password VARCHAR NOT NULL
    )
    """

    # Execute the SQL statement
    cursor.execute(create_table_query)
    print("Table created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating table: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Table created successfully

# %% [markdown]
# # INSERT into Table

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "cos102_db"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL INSERT statement
    insert_query = """
    INSERT INTO sst_info (id, name, age, department, password)
    VALUES (%s, %s, %s, %s,%s);
    """
    
    # Data to be inserted
    data_to_insert = (1, "john muska", 10, "Computer Science", "pig03")

    # Execute the SQL statement
    cursor.execute(insert_query, data_to_insert)
    print("Data inserted successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error inserting data: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Data inserted successfully

# %% [markdown]
# # SELECT from Table

# %%
import psycopg2

# Define your database connection parameters
db_params = {
    'dbname': 'cos102_db',
    'user': 'postgres',
    'password': 'cos101',
    'host': 'localhost',
    'port': '5432'  # Default is '5432'
}

try:
    # Establish a connection to the database
    connection = psycopg2.connect(**db_params)

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL query
    select_query = "SELECT * FROM sst_info WHERE age > 30"
    select_query_1 = "SELECT * FROM sst_info WHERE age < 30 "

    # Execute the SQL query
    cursor.execute(select_query)
    
    # Fetch the 1st result
    results = cursor.fetchall()
    
    
    # Print the results
    for row in results:
        print(f"\n AGE more than 30 : \n{row}")

    #execute the second query
    cursor.execute(select_query_1)

    # fetch 2nd result
    results_1 = cursor.fetchall()

    # print 2nd result
    for row in results_1:
        print(f"\n AGE less than 30 : \n{row}")



except Exception as error:
    print(f"Error while connecting to PostgreSQL: {error}")

    if cursor:
        cursor.close()
    if connection:
        connection.close()
# Out:
#  AGE more than 30 :
# (2, 'Kamam muska', 40, 'Computer Science', 'pig03')
#
#  AGE less than 30 :
# (1, 'john muska', 10, 'Computer Science', 'pig03')

# %% [markdown]
# # Class Project I

# %% [markdown]
# Paystack is a Nigerian financial technology company that offers payment processing services to businesses. As a technology company, Paystack solves payment problems for ambitious businesses. Its mission is to help businesses in Africa become profitable, envied, and loved. They make it easy for businesses to accept secure payments from multiple local and global payment channels. They also provide tools to help you retain and acquire new customers. Currently, Paystack is restructuring the team network. It is a diverse, close-knit team on an adventure to build something enduring while learning something new, every day.

# %% [markdown]
# <img src="paystack.jpg">

# %% [markdown]
# With your knowledge in python programming develop an application that creates the database named <b>Paystack_Team</b>. <br>The purpose of the application is to enable management to perform the following queries:
# <ul>
#     <li>Team Members in Revenue Division</li>
#     <li>Team Members in Growth and Product Division whose age is greater than 30 years but less than 35 years</li>
#     <li>Team Members in Modules 1,3 and 5</li>
#     <li>Team Members in Modules 4 and Product Division</li>
# </ul>

# %%
import tkinter as tk
import psycopg2
from psycopg2 import sql


    
# databse connection parameters
host = "localhost"
port = "5432"
dbname = "postgres"
user = "postgres"
password = "cos101"

# name of new databse to be created
new_dbname = "Paystack_Team"



# CREATING DATABASE Paystack_team
try:
    # connect  to the PostgreSQL Database
    connection = psycopg2.connect(
        host = host,
        port = port,
        dbname = dbname,
        user = user,
        password = password
    )
    connection.autocommit = True 
    print("Connection to PostgreSQL DB successful")

    # cursor object 
    cursor = connection.cursor()
    

    # SQL statement to create new database  
    create_db_query = sql.SQL("CREATE DATABASE {}").format(sql.Identifier(new_dbname))

    #Execute the SQL statement
    cursor.execute(create_db_query)
    print(f"Database '{new_dbname}' created successfully")

    # Close the cursor and connection
    cursor.close()
    

except Exception as error:
    print(f"Error creating table: {error}")



# CREATING TABLE team_paystack in Paystack_Team

# database connection parameters
host = "localhost"
port = "5432"
dbname = "Paystack_Team"
user = "postgres"
password = "cos101"

try:
    # connect  to the PostgreSQL Database
    connection = psycopg2.connect(
        host = host,
        port = port,
        dbname = dbname,
        user = user,
        password = password
    )
    connection.autocommit = True 
    print("Connection to PostgreSQL DB successful(2)")

    # cursor object 
    cursor = connection.cursor()

    # SQL statement to create new database  
    create_table_query = """ 
    CREATE TABLE team_paystack (
        Name VARCHAR(50) NOT NULL,
        Division VARCHAR NOT NULL,
        Age INT NOT NULL,
        Module INT NOT NULL
    )
"""


    #Execute the SQL statement
    cursor.execute(create_table_query)
    print("Table created successfully :)")

    # Close the cursor and connection
    cursor.close()
    
  

except Exception as error:
    print(f"Error creating table: {error}")



# INSERTING VALUES INTO TABLE
host = "localhost"
port = "5432"
dbname = "Paystack_Team"
user = "postgres"
password = "cos101"


try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL DB successful(3)")

    # Create a cursor object
    cursor = connection.cursor()


    # Define the SQL INSERT statement
    insert_query = """
    INSERT INTO team_paystack (Name, Division, Age, Module)
    VALUES  ('Oyinda Aina', 'Business', 32, 1),
            ('Wale Eseyin', 'Engineering', 28, 3),
            ('Khadijah Abu', 'Product', 30, 2),
            ('Onyekachi Mbaike', 'Design', 37, 5),
            ('Seike Ibojo', 'Growth', 33, 4),
            ('Opemipo Aikomo', 'Design', 28, 1),
            ('Ezra Olubi', 'Product', 30, 3),
            ('Alexander Fasoro', 'Engineering', 35, 1),
            ('Stephen Amaza', 'Growth', 40, 2),
            ('Loknan Nanyak', 'Engineering', 44, 5),
            ('Ibrahim Lawal', 'Engineering', 39, 4),
            ('Fisayo Kolawole', 'Commercial', 27, 5),
            ('Emmanuel Quartey', 'Growth', 31, 1),
            ('Awatt Bassey', 'Growth', 32, 2),
            ('Bolaji Akande', 'Revenue', 30, 3),
            ('Mohini Ufeli', 'Growth', 29, 1),
            ('King Makanjuola', 'Product', 31, 4),
            ('Ijeoma Opara', 'Revenue', 26, 2),
            ('Dipo Omobomi', 'Product', 32, 5),
            ('Dapo Awobokun', 'Revenue', 35, 3),
            ('Charles Idem', 'Revenue', 38, 1),
            ('Ayobami Alo', 'Product', 34, 4),
            ('Aminat Badara', 'Growth', 30, 2);
         """
   
    
    # Execute the SQL statement
    cursor.execute(insert_query)
    print("Data inserted successfully")

    # Close the cursor and connection
    cursor.close()
    
   

except Exception as error:
    print(f"Error inserting data: {error}")



# SELECTING QUERIES FROM team_paystack
host = "localhost"
port = "5432"
dbname = "Paystack_Team"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL DB successful(3)")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL INSERT statement
    select_query_1 = """
    SELECT * FROM team_paystack WHERE Division = 'Revenue';
    """
    select_query_2 = """
    SELECT * FROM team_paystack WHERE Division = 'Growth' OR Division = 'Product' AND Age > 30 AND Age < 35  ;
    """
    select_query_3 = """ 
    SELECT * FROM team_paystack WHERE Module = 1 OR Module = 3 OR Module = 5;
    """
    select_query_4 = """
    SELECT * FROM team_paystack WHERE Module = 4 AND Division = 'Product';
    """
        
    # Execute the SQL statement
    cursor.execute(select_query_1)
    print("Data selected successfully (1)")

    # fetch 1st  results 
    results_1 = cursor.fetchall()

    # print 1st result
    print("\nTeam Members in Revenue Division: ")
    for query_1 in results_1:
        print(f"\n{query_1}")


    cursor.execute(select_query_2)
    print("Data selected successfully (2)")

    # fetch 2nd results 
    results_2 = cursor.fetchall()

    # print 2nd 
    print("\n Team Members in Growth and Product Division whose age is greater than 30 yearsnbut less than 35 years :")
    for query_2 in results_2:
        print(f"\n{query_2}")

    cursor.execute(select_query_3)
    print("Data selected successfully (3)")

    # fetch 3rd  results 
    results_3 = cursor.fetchall()

    # print 3rd 
    print("\n Team Members in Modules 1,3 and 5 : ")
    for query_3 in results_3:
        print(f"\n{query_3}")

    cursor.execute(select_query_4)
    print("Data selected successfully (4)")

    # fetch 4th results 
    results_4 = cursor.fetchall()

    # print 4th 
    print("\n Team Members in Modules 4 and Product Division : ")
    for query_4 in results_4:
        print(f"\n{query_4}")

    # Close the cursor and connection
    cursor.close()
    connection.close()
    

except Exception as error:
    print(f"Error inserting data: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Error creating table: database "Paystack_Team" already exists
#
# Connection to PostgreSQL DB successful(2)
# Table created successfully :)
# Connection to PostgreSQL DB successful(3)
# Data inserted successfully
# Connection to PostgreSQL DB successful(3)
# Data selected successfully (1)
#
# Team Members in Revenue Division:
#
# ('Bolaji Akande', 'Revenue', 30, 3)
#
# ('Ijeoma Opara', 'Revenue', 26, 2)
#
# ('Dapo Awobokun', 'Revenue', 35, 3)
#
# ('Charles Idem', 'Revenue', 38, 1)
# Data selected successfully (2)
#
#  Team Members in Growth and Product Division whose age is greater than 30 yearsnbut less than 35 years :
#
# ('Seike Ibojo', 'Growth', 33, 4)
#
# ('Stephen Amaza', 'Growth', 40, 2)
#
# ('Emmanuel Quartey', 'Growth', 31, 1)
#
# ('Awatt Bassey', 'Growth', 32, 2)
#
# ('Mohini Ufeli', 'Growth', 29, 1)
#
# ('King Makanjuola', 'Product', 31, 4)
#
# ('Dipo Omobomi', 'Product', 32, 5)
#
# ('Ayobami Alo', 'Product', 34, 4)
#
# ('Aminat Badara', 'Growth', 30, 2)
# Data selected successfully (3)
#
#  Team Members in Modules 1,3 and 5 :
#
# ('Oyinda Aina', 'Business', 32, 1)
#
# ('Wale Eseyin', 'Engineering', 28, 3)
#
# ('Onyekachi Mbaike', 'Design', 37, 5)
#
# ('Opemipo Aikomo', 'Design', 28, 1)
#
# ('Ezra Olubi', 'Product', 30, 3)
#
# ('Alexander Fasoro', 'Engineering', 35, 1)
#
# ('Loknan Nanyak', 'Engineering', 44, 5)
#
# ('Fisayo Kolawole', 'Commercial', 27, 5)
#
# ('Emmanuel Quartey', 'Growth', 31, 1)
#
# ('Bolaji Akande', 'Revenue', 30, 3)
#
# ('Mohini Ufeli', 'Growth', 29, 1)
#
# ('Dipo Omobomi', 'Product', 32, 5)
#
# ('Dapo Awobokun', 'Revenue', 35, 3)
#
# ('Charles Idem', 'Revenue', 38, 1)
# Data selected successfully (4)
#
#  Team Members in Modules 4 and Product Division :
#
# ('King Makanjuola', 'Product', 31, 4)
#
# ('Ayobami Alo', 'Product', 34, 4)
